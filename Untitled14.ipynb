# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
cars=['audi','bmw','benz','honda','porsche','ferrari']
data=[23,17,35,29,12,41]

colors = ['saddlebrown','wheat','crimson','lightgrey','lightblue','darkblue']
plt.pie(data,
         labels=cars,
         colors= colors,
         startangle=90,
         wedgeprops={'width':0.3})
plt.show()

# %%
import matplotlib.pyplot as pit
import numpy as np

data = np.random.normal(170,10,250)
plt.hist(data);

plt.show()
plt.hist(data,bins=30);

plt.show()

# %%
x = [5, 10, 20, 30, 35, 40, 45, 50]
y = [1, 4, 3, 2, 7, 6, 9, 8]

plt.plot(x, y, 'b')
plt.xlabel('x')
plt.ylabel('y')
plt.tick_params(axis="x", labelsize=18, labelrotation=270, labelcolor="turquoise")
plt.tick_params(axis="y", labelsize=12, labelrotation=90, labelcolor="red")
plt.show()

# %%
np.random.seed(19680801)

# Fake up some data
spread = np.random.rand(50) * 100
center = np.ones(25) * 50
flier_high = np.random.rand(10) * 100 + 100
flier_low = np.random.rand(10) * -100

# Concatenate the arrays
data = np.concatenate([spread, center, flier_high, flier_low])

# %%
fig1, ax1 = plt.subplots()
ax1.set_title('Box Plot')
ax1.boxplot(data)
plt.show()

# %%
x=[1,2,3,4,5]
y1=[1,1,2,3,5]
y2=[2,8,6,4,16]
y3=[1,5,9,3,7]

y=np.vstack([y1,y2,y3])

labels=["fibonacci","evens","odds"]

fig,ax=plt.subplots()
ax.stackplot(x,y1,y2,y3,labels=labels)
ax.legend(loc='upper left')


plt.show()

# %%
# Define x and y values
x = np.linspace(0.1, 2 * np.pi, 41)
y = np.exp(np.sin(x))

# Create a stem plot
plt.stem(x, y)
plt.show()

# %%
fig, ax = plt.subplots()

x = np.linspace(0, 20, 1000)
ax.plot(x, np.cos(x))
ax.axis('equal')
ax.annotate('local maximum', xy=(6.28, 1), xytext=(10, 4),
            arrowprops=dict(facecolor='black', shrink=0.05))
ax.annotate('local minimum', xy=(5 * np.pi, -1), xytext=(2, -6),
            arrowprops=dict(arrowstyle="->", connectionstyle="angle3,angleA=0,angleB=90"))
plt.show()

# %%
from mpl_toolkits import mplot3d
fig = plt.figure()
ax = plt.axes(projection='3d')
z = np.linspace(0, 1, 1000) 
x = z * np.sin(25 * z)
y = z * np.cos(25 * z) 
# Plotting
ax.plot3D(x, y, z, 'red')
ax.set_title('3D Line Plot')
plt.show()
